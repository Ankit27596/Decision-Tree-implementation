# %% [markdown]
# # <b>Assignment : DT</b>

# %% [markdown]
# <font color='red'><b> Please check below video before attempting this assignment</b></font>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ZhLXULFjIjQ', width="1000",height="500")

# %% [markdown]
# <font color='red'><b> TF-IDFW2V</b></font>

# %% [markdown]
# <b>Tfidf w2v (w1,w2..) = (tfidf(w1) * w2v(w1) + tfidf(w2) * w2v(w2) + …)  /    (tfidf(w1) + tfidf(w2) + …)</b>

# %% [markdown]
# <b>(Optional) Please check course video on [AVgw2V and TF-IDFW2V ](https://www.appliedaicourse.com/lecture/11/applied-machine-learning-online-course/2916/avg-word2vec-tf-idf-weighted-word2vec/3/module-3-foundations-of-natural-language-processing-and-machine-learning)for more details.

# %% [markdown]
# <font color='blue'><b>Glove vectors </b></font>

# %% [markdown]
# <b>In this assignment you will be working with glove vectors , please check  [this](https://en.wikipedia.org/wiki/GloVe_(machine_learning)) and [this](https://en.wikipedia.org/wiki/GloVe_(machine_learning)) for more details.</b><br>
#
# Download glove vectors from this [link ](https://drive.google.com/file/d/1lDca_ge-GYO0iQ6_XDLWePQFMdAA2b8f/view?usp=sharing)

# %%
#please use below code to load glove vectors 
import pickle
with open('glove_vectors', 'rb') as f:
    model = pickle.load(f)
    glove_words =  set(model.keys())

# %% [markdown]
# or else , you can use below code

# %%
'''
# Reading glove vectors in python: https://stackoverflow.com/a/38230349/4084039
def loadGloveModel(gloveFile):
    print ("Loading Glove Model")
    f = open(gloveFile,'r', encoding="utf8")
    model = {}
    for line in tqdm(f):
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print ("Done.",len(model)," words loaded!")
    return model
model = loadGloveModel('glove.42B.300d.txt')

# ============================
Output:
    
Loading Glove Model
1917495it [06:32, 4879.69it/s]
Done. 1917495  words loaded!

# ============================

words = []
for i in preproced_texts:
    words.extend(i.split(' '))

for i in preproced_titles:
    words.extend(i.split(' '))
print("all the words in the coupus", len(words))
words = set(words)
print("the unique words in the coupus", len(words))

inter_words = set(model.keys()).intersection(words)
print("The number of words that are present in both glove vectors and our coupus", \
      len(inter_words),"(",np.round(len(inter_words)/len(words)*100,3),"%)")

words_courpus = {}
words_glove = set(model.keys())
for i in words:
    if i in words_glove:
        words_courpus[i] = model[i]
print("word 2 vec length", len(words_courpus))


# stronging variables into pickle files python: http://www.jessicayung.com/how-to-use-pickle-to-save-and-load-variables-in-python/

import pickle
with open('glove_vectors', 'wb') as f:
    pickle.dump(words_courpus, f)


'''
# Out:
# '\n# Reading glove vectors in python: https://stackoverflow.com/a/38230349/4084039\ndef loadGloveModel(gloveFile):\n    print ("Loading Glove Model")\n    f = open(gloveFile,\'r\', encoding="utf8")\n    model = {}\n    for line in tqdm(f):\n        splitLine = line.split()\n        word = splitLine[0]\n        embedding = np.array([float(val) for val in splitLine[1:]])\n        model[word] = embedding\n    print ("Done.",len(model)," words loaded!")\n    return model\nmodel = loadGloveModel(\'glove.42B.300d.txt\')\n\n# ============================\nOutput:\n    \nLoading Glove Model\n1917495it [06:32, 4879.69it/s]\nDone. 1917495  words loaded!\n\n# ============================\n\nwords = []\nfor i in preproced_texts:\n    words.extend(i.split(\' \'))\n\nfor i in preproced_titles:\n    words.extend(i.split(\' \'))\nprint("all the words in the coupus", len(words))\nwords = set(words)\nprint("the unique words in the coupus", len(words))\n\ninter_words = set(model.keys()).intersection(wo
# ...

# %% [markdown]
# # <font color='red'> <b>Task - 1</b></font>

# %% [markdown]
# <ol>
#     <li><strong>Apply Decision Tree Classifier(DecisionTreeClassifier) on these feature sets</strong>
#         <ul>
#             <li><font color='red'>Set 1</font>: categorical, numerical features +  preprocessed_essay (TFIDF) + Sentiment scores(preprocessed_essay)</li>
#             <li><font color='red'>Set 2</font>: categorical, numerical features +  preprocessed_essay (TFIDF W2V) + Sentiment scores(preprocessed_essay)</li>        </ul>
#     </li>
#     <li><strong>The hyper paramter tuning (best `depth` in range [1, 3, 10, 30], and the best `min_samples_split` in range [5, 10, 100, 500])</strong>
#         <ul>
#     <li>Find the best hyper parameter which will give the maximum <a href='https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/receiver-operating-characteristic-curve-roc-curve-and-auc-1/'>AUC</a> value</li>
#     <li>find the best hyper paramter using k-fold cross validation(use gridsearch cv or randomsearch cv)/simple cross validation data(you can write your own for loops refer sample solution)</li>
#         </ul>
#     </li>
#     <li>
#     <strong>Representation of results</strong>
#         <ul>
#     <li>You need to plot the performance of model both on train data and cross validation data for each hyper parameter, like shown in the figure
#     <img src='https://i.imgur.com/Gp2DQmh.jpg' width=500px> with X-axis as <strong>min_sample_split</strong>, Y-axis as <strong>max_depth</strong>, and Z-axis as <strong>AUC Score</strong> , we have given the notebook which explains how to plot this 3d plot, you can find it in the same drive <i>3d_scatter_plot.ipynb</i></li>
#             <p style="text-align:center;font-size:30px;color:red;"><strong>or</strong></p> <br>
#     <li>You need to plot the performance of model both on train data and cross validation data for each hyper parameter, like shown in the figure
#     <img src='https://i.imgur.com/fgN9aUP.jpg' width=300px> <a href='https://seaborn.pydata.org/generated/seaborn.heatmap.html'>seaborn heat maps</a> with rows as <strong>min_sample_split</strong>, columns as <strong>max_depth</strong>, and values inside the cell representing <strong>AUC Score</strong> </li>
#     <li>You choose either of the plotting techniques out of 3d plot or heat map</li>
#     <li>Once after you found the best hyper parameter, you need to train your model with it, and find the AUC on test data and plot the ROC curve on both train and test.
#         Make sure that you are using predict_proba method to calculate AUC curves, because AUC is calcualted on class probabilities and not on class labels.
#     <img src='https://i.imgur.com/wMQDTFe.jpg' width=300px></li>
#     <li>Along with plotting ROC curve, you need to print the <a href='https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/confusion-matrix-tpr-fpr-fnr-tnr-1/'>confusion matrix</a> with predicted and original labels of test data points
#     <img src='https://i.imgur.com/IdN5Ctv.png' width=300px></li>
#     <li>Once after you plot the confusion matrix with the test data, get all the `false positive data points`
#         <ul>
#             <li> Plot the WordCloud(https://www.geeksforgeeks.org/generating-word-cloud-python/) with the words of essay text of these `false positive data points`</li>
#             <li> Plot the box plot with the `price` of these `false positive data points`</li>
#             <li> Plot the pdf with the `teacher_number_of_previously_posted_projects` of these `false positive data points`</li>
#         </ul>
#         </ul>
#     </li>

# %% [markdown]
# # <font color='red'><b> Task - 2 </b></font>

# %% [markdown]
# For this task consider **set-1** features.
#
# *  Select all the features which are having non-zero feature importance.You can get the feature importance using  'feature_importances_`
#    (https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html), discard the all other remaining features and then apply any of the model of you choice i.e. (Dession tree, Logistic Regression, Linear SVM).
# *  You need to do hyperparameter tuning corresponding to the model you selected and procedure in step 2 and step 3<br>
#   **Note**: when you want to find the feature importance make sure you don't use max_depth parameter keep it None.
#   </li>
#     <br>
# You need to summarize the results at the end of the notebook, summarize it in the table format
#         <img src='http://i.imgur.com/YVpIGGE.jpg' width=400px>
#     </li>
# </ol>

# %% [markdown]
# <font color='blue'><b>Hint for calculating Sentiment scores</b></font>

# %%
# import nltk
# nltk.download('vader_lexicon')

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# import nltk
nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()

sample_sentence_1='I am happy.'
ss_1 = sid.polarity_scores(sample_sentence_1)
print('sentiment score for sentence 1',ss_1)

sample_sentence_2='I am sad.'
ss_2 = sid.polarity_scores(sample_sentence_2)
print('sentiment score for sentence 2',ss_2)

sample_sentence_3='I am going to New Delhi tommorow.'
ss_3 = sid.polarity_scores(sample_sentence_3)
print('sentiment score for sentence 3',ss_3)
# Out:
# sentiment score for sentence 1 {'neg': 0.0, 'neu': 0.213, 'pos': 0.787, 'compound': 0.5719}
# sentiment score for sentence 2 {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'compound': -0.4767}
# sentiment score for sentence 3 {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# <h1> Decision Tree </h1>

# %% [markdown]
# # <font color='red'> <b>Task - 1</b></font>

# %% [markdown]
# ## 1.1 Loading Data

# %%
#make sure you are loading atleast 50k datapoints
#you can work with features of preprocessed_data.csv for the assignment.
import pandas
data = pandas.read_csv('preprocessed_data.csv', nrows=50000)

# %%
# write your code in following steps for task 1
# 1. calculate sentiment scores for the essay feature 
# 2. Split your data.
# 3. perform tfidf vectorization of text data.
# 4. perform tfidf w2v vectorization of text data.
# 5. perform encoding of categorical features.
# 6. perform encoding of numerical features
# 7. For task 1 set 1 stack up all the features
# 8. For task 1 set 2 stack up all the features (for stacking dense features you can use np.stack)
# 9. Perform hyperparameter tuning and plot either heatmap or 3d plot.
# 10. Find the best parameters and fit the model. Plot ROC-AUC curve(using predict proba method)
# 11. Plot confusion matrix based on best threshold value
# 12. Find all the false positive data points and plot wordcloud of essay text and pdf of teacher_number_of_previously_posted_projects.
# 13. Write your observations about the wordcloud and pdf.

# %%
from tqdm import tqdm
negative=[]
positive=[]
neutral=[]
compound=[]
for i in tqdm(data['essay']):
    j=sid.polarity_scores(i)['neg']
    k=sid.polarity_scores(i)['neu']
    l=sid.polarity_scores(i)['pos']
    m=sid.polarity_scores(i)['compound']
    negative.append(j)
    neutral.append(k)
    positive.append(l)
    compound.append(m)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 50000/50000 [13:48<00:00, 60.36it/s]

# %%
data['negative']=negative
data['positive']=positive
data['neutral']=neutral
data['compoud']=compound

# %%
data.head(2)
# Out:
#   school_state teacher_prefix project_grade_category  \
# 0           ca            mrs          grades_prek_2
# 1           ut             ms             grades_3_5
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                            53                    1
# 1                                             4                    1
#
#   clean_categories                 clean_subcategories  \
# 0     math_science  appliedsciences health_lifescience
# 1     specialneeds                        specialneeds
#
#                                                essay   price  negative  \
# 0  i fortunate enough use fairy tale stem kits cl...  725.05     0.013
# 1  imagine 8 9 years old you third grade classroo...  213.03     0.072
#
#    positive  neutral  compoud
# 0     0.205    0.783   0.9867
# 1     0.248    0.680   0.9897

# %% [markdown]
# **splitting data**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(
    data, data['project_is_approved'],
    test_size=0.2,
    random_state=42,
    stratify=data['project_is_approved'])

print('x_train:', x_train.shape)
print('x_test:', x_test.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)
# Out:
# x_train: (40000, 13)
# x_test: (10000, 13)
# y_train: (40000,)
# y_test: (10000,)

# %%
x_train, x_cv, y_train, y_cv= train_test_split(x_train, y_train, test_size=0.25, stratify=y_train)

print('x_train:', x_train.shape)
print('y_train:', y_train.shape)
print('x_cv:', x_cv.shape)
print('y_cv:', y_cv.shape)
print('x_test:', x_test.shape)
print('y_test:', y_test.shape)
# Out:
# x_train: (30000, 13)
# y_train: (30000,)
# x_cv: (10000, 13)
# y_cv: (10000,)
# x_test: (10000, 13)
# y_test: (10000,)

# %% [markdown]
# **encoding text data**

# %%
preprocessed_essays=data['essay'].values
train_preprocessed_essays= x_train['essay'].values
test_preprocessed_essays=x_test['essay'].values
cv_preprocessed_essays=x_cv['essay'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=10)
vectorizer.fit(train_preprocessed_essays)

tfidf_essay=vectorizer.get_feature_names()

train_text_tfidf=vectorizer.transform(train_preprocessed_essays)
print('shape of matrix after one hot encoding:', train_text_tfidf.shape)
# Out:
# shape of matrix after one hot encoding: (30000, 9927)

# %%
test_text_tfidf=vectorizer.transform(test_preprocessed_essays)
print('shape of matrix after one hot encoding:', test_text_tfidf.shape)
# Out:
# shape of matrix after one hot encoding: (10000, 9927)

# %%
cv_text_tfidf=vectorizer.transform(cv_preprocessed_essays)
print('shape of matrix after one hot encoding:', cv_text_tfidf.shape)
# Out:
# shape of matrix after one hot encoding: (10000, 9927)

# %% [markdown]
# **vectorizing categorical data**

# %%
from sklearn.feature_extraction.text import CountVectorizer
from collections import Counter
my_counter= Counter()
for word in data['clean_categories'].values:
    my_counter.update(word.split())

cat_dict= dict(my_counter)
sorted_cat_dict= dict(sorted(cat_dict.items(), key=lambda kv: kv[1]))
vectorizer= CountVectorizer(vocabulary=list(sorted_cat_dict.keys()), lowercase=False, binary= True)

vectorizer.fit(x_train['clean_categories'].values)
train_cat_onehot=vectorizer.fit_transform(x_train['clean_categories'].values)
test_cat_onehot=vectorizer.transform(x_test['clean_categories'].values)
cv_cat_onehot=vectorizer.transform(x_cv['clean_categories'].values)

cat_feat=vectorizer.get_feature_names()
print(cat_feat)
print('shape of Train matrix after one hot encoding', train_cat_onehot.shape)
print('shape of Test matrix after one hot encoding', test_cat_onehot.shape)
print('shape of cv matrix after one hot encoding', cv_cat_onehot.shape)
# Out:
# ['warmth', 'care_hunger', 'history_civics', 'music_arts', 'appliedlearning', 'specialneeds', 'health_sports', 'math_science', 'literacy_language']
# shape of Train matrix after one hot encoding (30000, 9)
# shape of Test matrix after one hot encoding (10000, 9)
# shape of cv matrix after one hot encoding (10000, 9)

# %%
from collections import Counter
my_counter1= Counter()
for word in data['clean_subcategories'].values:
    my_counter1.update(word.split())
cat_sub_dict=dict(my_counter1)
sorted_sub_cat_dict=dict(sorted(cat_sub_dict.items(), key=lambda kv: kv[1]))

vectorizer= CountVectorizer(vocabulary=list(sorted_sub_cat_dict), lowercase=False, binary= True)
vectorizer.fit(x_train['clean_subcategories'].values)
train_sub_cat_onehot=vectorizer.transform(x_train['clean_subcategories'].values)
test_sub_cat_onehot=vectorizer.transform(x_test['clean_subcategories'].values)
cv_sub_cat_onehot=vectorizer.transform(x_cv['clean_subcategories'].values)

sub_cat_feat=vectorizer.get_feature_names()

print(sub_cat_feat)
print('shape of Train matrix after one hot encoding -> clean_subcategories:', train_sub_cat_onehot.shape)
print('shape of Test matrix after one hot encoding -> clean_subcategories:', test_sub_cat_onehot.shape)
print('shape of cv matrix after one hot encoding -> clean_subcategories:', cv_sub_cat_onehot.shape)
# Out:
# ['warmth', 'care_hunger', 'financialliteracy', 'economics', 'parentinvolvement', 'communityservice', 'extracurricular', 'foreignlanguages', 'civics_government', 'performingarts', 'teamsports', 'socialsciences', 'charactereducation', 'nutritioneducation', 'college_careerprep', 'other', 'music', 'history_geography', 'esl', 'health_lifescience', 'earlydevelopment', 'environmentalscience', 'visualarts', 'gym_fitness', 'appliedsciences', 'specialneeds', 'health_wellness', 'literature_writing', 'mathematics', 'literacy']
# shape of Train matrix after one hot encoding -> clean_subcategories: (30000, 30)
# shape of Test matrix after one hot encoding -> clean_subcategories: (10000, 30)
# shape of cv matrix after one hot encoding -> clean_subcategories: (10000, 30)

# %%
my_counter2 = Counter()
for word in data["school_state"].values:
    my_counter2.update(word.split())
    
state_ct_dict=dict(my_counter2)
sorted_state_ct_dict=dict(sorted(state_ct_dict.items(), key=lambda kv:kv[1]))

vectorizer=CountVectorizer(vocabulary=list(sorted_state_ct_dict.keys()), lowercase=False, binary=True)
vectorizer.fit(x_train['school_state'].values)

school_feat=vectorizer.get_feature_names()

train_state_onehot=vectorizer.fit_transform(x_train['school_state'].values)
test_state_onehot=vectorizer.fit_transform(x_test['school_state'].values)
cv_state_onehot=vectorizer.fit_transform(x_cv['school_state'].values)

print(school_feat)
print('shape of Train matrix after onehot encoding -> school_state:', train_state_onehot.shape)
print('shape of Test matrix after onehot encoding -> school_state:', test_state_onehot.shape)
print('shape of cv matrix after onehot encoding -> school_state:', cv_state_onehot.shape)
# Out:
# ['wy', 'vt', 'nd', 'mt', 'ri', 'sd', 'nh', 'ne', 'ak', 'de', 'hi', 'me', 'nm', 'dc', 'wv', 'ks', 'id', 'ia', 'co', 'mn', 'ar', 'ky', 'ms', 'nv', 'or', 'ct', 'al', 'md', 'nj', 'wi', 'tn', 'va', 'ut', 'az', 'wa', 'ma', 'ok', 'oh', 'la', 'in', 'mo', 'mi', 'pa', 'sc', 'il', 'ga', 'nc', 'ny', 'fl', 'tx', 'ca']
# shape of Train matrix after onehot encoding -> school_state: (30000, 51)
# shape of Test matrix after onehot encoding -> school_state: (10000, 51)
# shape of cv matrix after onehot encoding -> school_state: (10000, 51)

# %%
my_counter3=Counter()
for word in data['project_grade_category'].values:
    my_counter3.update(word.split())
project_cat_dict=dict(my_counter3)
sorted_project_cat_dict=dict(sorted(project_cat_dict.items(), key=lambda kv:kv[1]))

vectorizer=CountVectorizer(vocabulary=list(sorted_project_cat_dict.keys()), lowercase=False, binary=True)
vectorizer.fit(x_train['project_grade_category'])
print(vectorizer.get_feature_names())

train_grade_onehot=vectorizer.fit_transform(x_train['project_grade_category'].values)
test_grade_onehot=vectorizer.fit_transform(x_test['project_grade_category'].values)
cv_grade_onehot=vectorizer.fit_transform(x_cv['project_grade_category'].values)

print('shape of Train matrix after onehot encoding -> project_grade_category:', train_grade_onehot.shape)
print('shape of Test matrix after onehot encoding -> project_grade_category:', test_grade_onehot.shape)
print('shape of cv matrix after onehot encoding -> project_grade_category:', cv_grade_onehot.shape)
# Out:
# ['grades_9_12', 'grades_6_8', 'grades_3_5', 'grades_prek_2']
# shape of Train matrix after onehot encoding -> project_grade_category: (30000, 4)
# shape of Test matrix after onehot encoding -> project_grade_category: (10000, 4)
# shape of cv matrix after onehot encoding -> project_grade_category: (10000, 4)

# %%
my_counter4 = Counter()
for word in data['teacher_prefix'].values:
    my_counter4.update(word.split())
teacher_cat_dict = dict(my_counter4)
sorted_teacher_cat_dict = dict(sorted(teacher_cat_dict.items(), key=lambda kv: kv[1]))

vectorizer = CountVectorizer(vocabulary=list(sorted_teacher_cat_dict.keys()), lowercase=False, binary=True)
vectorizer.fit(x_train['teacher_prefix'])
print(vectorizer.get_feature_names())

train_teacher_one_hot = vectorizer.fit_transform(x_train['teacher_prefix'].values)
test_teacher_one_hot = vectorizer.transform(x_test['teacher_prefix'].values)
cv_teacher_one_hot = vectorizer.transform(x_cv['teacher_prefix'].values)

print("Shape of Train matrix after one hot encodig -> teacher_prefix ",train_teacher_one_hot.shape)
print("Shape of Test matrix after one hot encodig -> teacher_prefix",test_teacher_one_hot.shape)
print("Shape of CV matrix after one hot encodig -> teacher_prefix",cv_teacher_one_hot.shape)
# Out:
# ['dr', 'teacher', 'mr', 'ms', 'mrs']
# Shape of Train matrix after one hot encodig -> teacher_prefix  (30000, 5)
# Shape of Test matrix after one hot encodig -> teacher_prefix (10000, 5)
# Shape of CV matrix after one hot encodig -> teacher_prefix (10000, 5)

# %% [markdown]
# **tfidf w2v**

# %%
tfidf_model=TfidfVectorizer()
tfidf_model.fit(train_preprocessed_essays)
dictionary=dict(zip(tfidf_model.get_feature_names(), list(tfidf_model.idf_)))
tfidf_words=set(tfidf_model.get_feature_names())

# %%
import numpy as np
train_essay_tfidf_w2v=[]
for sentence in tqdm(train_preprocessed_essays):
    vector=np.zeros(300)
    tf_idf_weight=0
    for word in sentence.split():
        if (word in glove_words) and (word in tfidf_words):
            vec=model[word]
            tf_idf = dictionary[word]*(sentence.count(word)/len(sentence.split()))
            vector += (vec*tf_idf)
            tf_idf_weight += tf_idf
    if tf_idf_weight != 0:
        vector/=tf_idf_weight
    train_essay_tfidf_w2v.append(vector)
        
print(len(train_essay_tfidf_w2v))
print(len(train_essay_tfidf_w2v[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb0523f29565> in <module>
#       1 import numpy as np
#       2 train_essay_tfidf_w2v=[]
# ----> 3 for sentence in tqdm(train_preprocessed_essays):
#       4     vector=np.zeros(300)
#       5     tf_idf_weight=0
#
# NameError: name 'tqdm' is not defined

# %%
test_essay_tfidf_w2v=[]
for sentence in tqdm(test_preprocessed_essays):
    vector=np.zeros(300)
    tf_idf_weight=0
    for word in sentence.split():
        if (word in glove_words) and (word in tfidf_words):
            vec=model[word]
            tf_idf = dictionary[word]*(sentence.count(word)/len(sentence.split()))
            vector += (vec*tf_idf)
            tf_idf_weight += tf_idf
    if tf_idf_weight != 0:
        vector/=tf_idf_weight
    test_essay_tfidf_w2v.append(vector)
        
print(len(test_essay_tfidf_w2v))
print(len(test_essay_tfidf_w2v[0]))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:44<00:00, 225.88it/s]
# 10000
# 300

# %%
cv_essay_tfidf_w2v=[]
for sentence in tqdm(cv_preprocessed_essays):
    vector=np.zeros(300)
    tf_idf_weight=0
    for word in sentence.split():
        if (word in glove_words) and (word in tfidf_words):
            vec=model[word]
            tf_idf = dictionary[word]*(sentence.count(word)/len(sentence.split()))
            vector += (vec*tf_idf)
            tf_idf_weight += tf_idf
    if tf_idf_weight != 0:
        vector/=tf_idf_weight
    cv_essay_tfidf_w2v.append(vector)
        
print(len(cv_essay_tfidf_w2v))
print(len(cv_essay_tfidf_w2v[0]))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10000/10000 [00:41<00:00, 243.77it/s]
# 10000
# 300

# %% [markdown]
# **vectorizing numerical data**

# %%
data.columns
# Out:
# Index(['school_state', 'teacher_prefix', 'project_grade_category',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'clean_categories', 'clean_subcategories', 'essay', 'price', 'negative',
#        'positive', 'neutral', 'compoud'],
#       dtype='object')

# %%
from sklearn.preprocessing import Normalizer
price_normalizer=Normalizer()
price_normalizer.fit(x_train['price'].values.reshape(1, -1))
x_train_price_norm= price_normalizer.transform(x_train['price'].values.reshape(1, -1)).reshape(-1, 1)
x_cv_price_norm= price_normalizer.transform(x_cv['price'].values.reshape(1, -1)).reshape(-1, 1)
x_test_price_norm= price_normalizer.transform(x_test['price'].values.reshape(1, -1)).reshape(-1, 1)

print('shape of matrix after normalization -> price: x_train', x_train_price_norm.shape)
print('shape of matrix after normalization -> price: x_cv', x_cv_price_norm.shape)
print('shape of matrix after normalization -> price: x_test', x_test_price_norm.shape)
# Out:
# shape of matrix after normalization -> price: x_train (30000, 1)
# shape of matrix after normalization -> price: x_cv (10000, 1)
# shape of matrix after normalization -> price: x_test (10000, 1)

# %%
teacher_previous_projects_norm= Normalizer()
teacher_previous_projects_norm.fit(x_train['teacher_number_of_previously_posted_projects'].values.reshape
                                                      (1,-1))
x_train_prev_proj_norm=teacher_previous_projects_norm.transform(x_train['teacher_number_of_previously_posted_projects']
                                                               .values.reshape(1,-1)).reshape(-1,1)
x_test_prev_proj_norm=teacher_previous_projects_norm.transform(x_test['teacher_number_of_previously_posted_projects']
                                                              .values.reshape(1,-1)).reshape(-1,1)
x_cv_prev_proj_norm=teacher_previous_projects_norm.transform(x_cv['teacher_number_of_previously_posted_projects']
                                                            .values.reshape(1,-1)).reshape(-1,1)

print('shape of matrix after normalization -> prev proj: x_train', x_train_prev_proj_norm.shape)
print('shape of matrix after normalization -> prev proj: x_test', x_test_prev_proj_norm.shape)
print('shape of matrix after normalization -> prev proj: x_cv', x_cv_prev_proj_norm.shape)
# Out:
# shape of matrix after normalization -> prev proj: x_train (30000, 1)
# shape of matrix after normalization -> prev proj: x_test (10000, 1)
# shape of matrix after normalization -> prev proj: x_cv (10000, 1)

# %%
data.columns
# Out:
# Index(['school_state', 'teacher_prefix', 'project_grade_category',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'clean_categories', 'clean_subcategories', 'essay', 'price', 'negative',
#        'positive', 'neutral', 'compoud'],
#       dtype='object')

# %%
essay_norm=Normalizer()
essay_norm.fit(x_train['positive'].values.reshape(1,-1))

x_train_positive_norm=essay_norm.transform(x_train['positive'].values.reshape(1,-1)).reshape(-1,1)
x_test_positive_norm=essay_norm.transform(x_test['positive'].values.reshape(1,-1)).reshape(-1,1)
x_cv_positive_norm=essay_norm.transform(x_cv['positive'].values.reshape(1,-1)).reshape(-1,1)

print('shape of matrix after normalization -> positive: x_train', x_train_positive_norm.shape)
print('shape of matrix after normalization -> positive: x_test', x_test_positive_norm.shape)
print('shape of matrix after normalization -> positive: x_cv', x_cv_positive_norm.shape)
# Out:
# shape of matrix after normalization -> positive: x_train (30000, 1)
# shape of matrix after normalization -> positive: x_test (10000, 1)
# shape of matrix after normalization -> positive: x_cv (10000, 1)

# %%
essay_norm.fit(x_train['negative'].values.reshape(1,-1))

x_train_negative_norm=essay_norm.transform(x_train['negative'].values.reshape(1,-1)).reshape(-1,1)
x_test_negative_norm=essay_norm.transform(x_test['negative'].values.reshape(1,-1)).reshape(-1,1)
x_cv_negative_norm=essay_norm.transform(x_cv['negative'].values.reshape(1,-1)).reshape(-1,1)

print('shape of matrix after normalization -> negative: x_train', x_train_negative_norm.shape)
print('shape of matrix after normalization -> negative: x_test', x_test_negative_norm.shape)
print('shape of matrix after normalization -> negative: x_cv', x_cv_negative_norm.shape)
# Out:
# shape of matrix after normalization -> negative: x_train (30000, 1)
# shape of matrix after normalization -> negative: x_test (10000, 1)
# shape of matrix after normalization -> negative: x_cv (10000, 1)

# %%
essay_norm.fit(x_train['compoud'].values.reshape(1,-1))

x_train_compoud_norm=essay_norm.transform(x_train['compoud'].values.reshape(1,-1)).reshape(-1,1)
x_test_compoud_norm=essay_norm.transform(x_test['compoud'].values.reshape(1,-1)).reshape(-1,1)
x_cv_compoud_norm=essay_norm.transform(x_cv['compoud'].values.reshape(1,-1)).reshape(-1,1)

print('shape of matrix after normalization -> compoud: x_train', x_train_compoud_norm.shape)
print('shape of matrix after normalization -> compoud: x_test', x_test_compoud_norm.shape)
print('shape of matrix after normalization -> compoud: x_cv', x_cv_compoud_norm.shape)
# Out:
# shape of matrix after normalization -> compoud: x_train (30000, 1)
# shape of matrix after normalization -> compoud: x_test (10000, 1)
# shape of matrix after normalization -> compoud: x_cv (10000, 1)

# %%
# please write all the code with proper documentation, and proper titles for each subsection
# go through documentations and blogs before you start coding
# first figure out what to do, and then think about how to do.
# reading and understanding error messages will be very much helpfull in debugging your code
# when you plot any graph make sure you use 
    # a. Title, that describes your plot, this will be very helpful to the reader
    # b. Legends if needed
    # c. X-axis label
    # d. Y-axis label

# %% [markdown]
# **Merging all**

# %%
from scipy.sparse import hstack

X_train=hstack((train_cat_onehot, train_sub_cat_onehot, train_state_onehot, train_grade_onehot, train_teacher_one_hot, 
               train_text_tfidf, x_train_prev_proj_norm, x_train_price_norm, x_train_positive_norm, x_train_negative_norm,
               x_train_compoud_norm)).tocsr()

print(X_train.shape, y_train.shape)
print(type(X_train))
# Out:
# (30000, 10031) (30000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
X_test=hstack((test_cat_onehot, test_sub_cat_onehot, test_state_onehot, test_grade_onehot, test_teacher_one_hot, 
               test_text_tfidf, x_test_prev_proj_norm, x_test_price_norm, x_test_positive_norm, x_test_negative_norm,
               x_test_compoud_norm)).tocsr()

print(X_test.shape, y_test.shape)
print(type(X_test))
# Out:
# (10000, 10031) (10000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
X_cv=hstack((cv_cat_onehot, cv_sub_cat_onehot, cv_state_onehot, cv_grade_onehot, cv_teacher_one_hot, 
               cv_text_tfidf, x_cv_prev_proj_norm, x_cv_price_norm, x_cv_positive_norm, x_cv_negative_norm,
               x_cv_compoud_norm)).tocsr()

print(X_cv.shape, y_cv.shape)
print(type(X_cv))
# Out:
# (10000, 10031) (10000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
import seaborn as sea

# %%
DT= DecisionTreeClassifier()
parameters= {'max_depth': [1, 3, 10, 30], 'min_samples_split': [5, 10, 100, 500]}

classifier= GridSearchCV(DT, parameters, cv=3, scoring='roc_auc', return_train_score=True)
clf1=classifier.fit(X_train, y_train)

# %%
train_auc=clf1.cv_results_['mean_train_score']
cv_auc=clf1.cv_results_['mean_test_score']
train_auc_std=clf1.cv_results_['std_train_score']
cv_auc_std=clf1.cv_results_['std_test_score']
bestMaxdepth_1=clf1.best_params_['max_depth']
bestMINSamplesplit_1=clf1.best_params_['min_samples_split']
bestScore_1=clf1.best_score_
print('~~BEST MAX DEPTH:',clf1.best_params_['max_depth'], '~~BEST MIN SAMPLE SPLT:',clf1.best_params_['min_samples_split'],
     '~~BEST SCORE:',clf1.best_score_)
# Out:
# ~~BEST MAX DEPTH: 10 ~~BEST MIN SAMPLE SPLT: 500 ~~BEST SCORE: 0.6213646297009977

# %%
import matplotlib.pyplot as plt
import pandas as pd
max_scores = pd.DataFrame(classifier.cv_results_).groupby(['param_min_samples_split', 'param_max_depth']).max().unstack(
            )[['mean_test_score', 'mean_train_score']]

fig, ax= plt.subplots(1,2, figsize=(20, 6))

sea.heatmap(max_scores.mean_train_score, annot = True, fmt='.4g', ax=ax[0])
sea.heatmap(max_scores.mean_test_score, annot = True, fmt='.4g', ax=ax[1])

ax[0].set_title('Train Set')
ax[1].set_title('CV Set')

plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.linear_model import SGDClassifier

dt_tfidf_testModel=DecisionTreeClassifier(class_weight='balanced', min_samples_split=bestMINSamplesplit_1,
                                          max_depth=bestMaxdepth_1)
dt_tfidf_testModel.fit(X_train, y_train)

y_train_pred=dt_tfidf_testModel.predict_proba(X_train)[:,1]
predictions_train_set1=dt_tfidf_testModel.predict(X_train)

y_test_pred=dt_tfidf_testModel.predict_proba(X_test)[:,1]
predictions_test_set1=dt_tfidf_testModel.predict(X_test)

train_fpr, train_tpr, tr_thresholds = roc_curve(y_train, y_train_pred)
test_fpr, test_tpr, te_thresholds = roc_curve(y_test, y_test_pred)

ax = plt.subplot()

auc_set1_train=auc(train_fpr, train_tpr)
auc_set1_test=auc(test_fpr, test_tpr)


ax.plot(train_fpr, train_tpr, label="Train AUC ="+str(auc(train_fpr, train_tpr)))
ax.plot(test_fpr, test_tpr, label="Test AUC ="+str(auc(test_fpr, test_tpr)))
plt.legend()
plt.xlabel("False Positive Rate(FPR)")
plt.ylabel("True Positive Rate(TPR)")
plt.title("AUC")
plt.grid(b=True, which='major', color='k', linestyle=':')
ax.set_facecolor("white")
plt.show()

# %%
def predict(proba, threshould, fpr, tpr):
    t = threshould[np.argmax(tpr*(1-fpr))]
    print("the maximum value of tpr*(1-fpr)", max(tpr*(1-fpr)), "for threshold", np.round(t,3))
    predictions = []
    for i in proba:
        if i>=t:
            predictions.append(1)
        else:
            predictions.append(0)

    return predictions

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
print('Test confusion matrix')
print(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)))

conf_matr_df_test= pd.DataFrame(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)), 
                                 range(2), range(2))
sns.set(font_scale=1.4)
sns.heatmap(conf_matr_df_test, annot=True,annot_kws={"size": 26}, fmt='g',cmap="YlGnBu")
# Out:
# Test confusion matrix
# the maximum value of tpr*(1-fpr) 0.37172489898897126 for threshold 0.388
# [[ 918  683]
#  [2954 5445]]
# the maximum value of tpr*(1-fpr) 0.37172489898897126 for threshold 0.388
# <AxesSubplot:>

# %%
FP_essay_test_set1=[]
FP_price_test_set1=[]
FP_previous_posted_test_set1=[]

def retrievingfalsepos(part):
    if part=='test':
        FP_test_indexes_set1=[]
        for i in range(len(y_test)):
            if y_test.values[i]==0 and predictions_test_set1[i]==1:
                FP_test_indexes_set1.append(i)
        for i in FP_test_indexes_set1:
            FP_essay_test_set1.append(x_test['essay'].values[i])
            FP_price_test_set1.append(x_test['price'].values[i])
            FP_previous_posted_test_set1.append(x_test['teacher_number_of_previously_posted_projects'].values[i])

# %%
retrievingfalsepos('test')

# %%
from wordcloud import WordCloud, STOPWORDS
def lststr(s):
    str1 =''
    for ele in s:
        str1 += ele
    return str1
    
wordcloud=WordCloud(width=500, height=300, background_color='white', min_font_size=10).generate(lststr(FP_essay_test_set1))

plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %%
plt.boxplot(FP_price_test_set1)
plt.title('Box Plot for Price in False Positive')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,3))
sns.distplot(FP_previous_posted_test_set1)
plt.title('PDF for Teacher number who previously posted projects in False Positives')
plt.xlabel('Teacher number who previously posted projects')
plt.legend()
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %% [markdown]
# **set 2**

# %%
X_train_w2v=hstack((train_cat_onehot, train_sub_cat_onehot, train_state_onehot, train_grade_onehot, train_teacher_one_hot, 
               train_essay_tfidf_w2v, x_train_prev_proj_norm, x_train_price_norm, x_train_positive_norm, x_train_negative_norm,
               x_train_compoud_norm)).tocsr()

print(X_train_w2v.shape, y_train.shape)
print(type(X_train_w2v))
# Out:
# (30000, 404) (30000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
X_test_w2v=hstack((test_cat_onehot, test_sub_cat_onehot, test_state_onehot, test_grade_onehot, test_teacher_one_hot, 
               test_essay_tfidf_w2v, x_test_prev_proj_norm, x_test_price_norm, x_test_positive_norm, x_test_negative_norm,
               x_test_compoud_norm)).tocsr()

print(X_test_w2v.shape, y_test.shape)
print(type(X_test_w2v))
# Out:
# (10000, 404) (10000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
X_cv_w2v=hstack((cv_cat_onehot, cv_sub_cat_onehot, cv_state_onehot, cv_grade_onehot, cv_teacher_one_hot, 
               cv_essay_tfidf_w2v, x_cv_prev_proj_norm, x_cv_price_norm, x_cv_positive_norm, x_cv_negative_norm,
               x_cv_compoud_norm)).tocsr()

print(X_cv_w2v.shape, y_cv.shape)
print(type(X_cv_w2v))
# Out:
# (10000, 404) (10000,)
# <class 'scipy.sparse.csr.csr_matrix'>

# %%
DT= DecisionTreeClassifier()
parameters= {'max_depth': [1, 3, 10, 30], 'min_samples_split': [5, 10, 100, 500]}

classifier= GridSearchCV(DT, parameters, cv=3, scoring='roc_auc', return_train_score=True)
clf2=classifier.fit(X_train_w2v, y_train)

# %%
train_auc2=clf2.cv_results_['mean_train_score']
cv_auc2=clf2.cv_results_['mean_test_score']
train_auc_std2=clf2.cv_results_['std_train_score']
cv_auc_std2=clf2.cv_results_['std_test_score']
bestMaxdepth_2=clf2.best_params_['max_depth']
bestMINSamplesplit_2=clf2.best_params_['min_samples_split']
bestScore_2=clf2.best_score_
print('~~BEST MAX DEPTH:',clf2.best_params_['max_depth'], '~~BEST MIN SAMPLE SPLT:',clf2.best_params_['min_samples_split'],
     '~~BEST SCORE:',clf2.best_score_)
# Out:
# ~~BEST MAX DEPTH: 10 ~~BEST MIN SAMPLE SPLT: 500 ~~BEST SCORE: 0.6146926582444135

# %%
max_scores2 = pd.DataFrame(classifier.cv_results_).groupby(['param_min_samples_split', 'param_max_depth']).max().unstack(
            )[['mean_test_score', 'mean_train_score']]

fig, ax= plt.subplots(1,2, figsize=(20, 6))

sea.heatmap(max_scores.mean_train_score, annot = True, fmt='.4g', ax=ax[0])
sea.heatmap(max_scores.mean_test_score, annot = True, fmt='.4g', ax=ax[1])

ax[0].set_title('Train Set2')
ax[1].set_title('CV Set2')

plt.show()

# %%
dt_tfidf_testModel2=DecisionTreeClassifier(class_weight='balanced', min_samples_split=bestMINSamplesplit_2,
                                          max_depth=bestMaxdepth_2)
dt_tfidf_testModel2.fit(X_train_w2v, y_train)

y_train_pred=dt_tfidf_testModel2.predict_proba(X_train_w2v)[:,1]
predictions_train_set2=dt_tfidf_testModel2.predict(X_train_w2v)

y_test_pred=dt_tfidf_testModel2.predict_proba(X_test_w2v)[:,1]
predictions_test_set2=dt_tfidf_testModel2.predict(X_test_w2v)

train_fpr, train_tpr, tr_thresholds = roc_curve(y_train, y_train_pred)
test_fpr, test_tpr, te_thresholds = roc_curve(y_test, y_test_pred)

ax = plt.subplot()

auc_set2_train=auc(train_fpr, train_tpr)
auc_set2_test=auc(test_fpr, test_tpr)


ax.plot(train_fpr, train_tpr, label="Train AUC ="+str(auc(train_fpr, train_tpr)))
ax.plot(test_fpr, test_tpr, label="Test AUC ="+str(auc(test_fpr, test_tpr)))
plt.legend()
plt.xlabel("False Positive Rate(FPR)")
plt.ylabel("True Positive Rate(TPR)")
plt.title("AUC set2")
plt.grid(b=True, which='major', color='k', linestyle=':')
ax.set_facecolor("white")
plt.show()

# %%
print('Test confusion matrix set 2')
print(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)))

conf_matr_df_test= pd.DataFrame(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)), 
                                 range(2), range(2))
sns.set(font_scale=1.4)
sns.heatmap(conf_matr_df_test, annot=True,annot_kws={"size": 26}, fmt='g',cmap="YlGnBu")
# Out:
# Test confusion matrix set 2
# the maximum value of tpr*(1-fpr) 0.3427386696268755 for threshold 0.48
# [[ 981  620]
#  [3701 4698]]
# the maximum value of tpr*(1-fpr) 0.3427386696268755 for threshold 0.48
# <AxesSubplot:>

# %%
FP_essay_test_set2=[]
FP_price_test_set2=[]
FP_previous_posted_test_set2=[]

def retrievingfalsepos(part):
    if part=='test':
        FP_test_indexes_set2=[]
        for i in range(len(y_test)):
            if y_test.values[i]==0 and predictions_test_set2[i]==1:
                FP_test_indexes_set2.append(i)
        for i in FP_test_indexes_set2:
            FP_essay_test_set2.append(x_test['essay'].values[i])
            FP_price_test_set2.append(x_test['price'].values[i])
            FP_previous_posted_test_set2.append(x_test['teacher_number_of_previously_posted_projects'].values[i])

# %%
retrievingfalsepos('test')

# %%
def lststr(s):
    str1 =''
    for ele in s:
        str1 += ele
    return str1
    
wordcloud=WordCloud(width=500, height=300, background_color='white', min_font_size=10).generate(lststr(FP_essay_test_set2))

plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %%
plt.boxplot(FP_price_test_set2)
plt.title('Box Plot for Price in False Positive set 2')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
 plt.figure(figsize=(10,3))
sns.distplot(FP_previous_posted_test_set2)
plt.title('PDF for Teacher number who previously posted projects in False Positives set 2')
plt.xlabel('Teacher number who previously posted projects')
plt.legend()
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %% [markdown]
# # <font color='red'> <b>Task - 2</b></font>

# %%
# 1. write your code in following steps for task 2
# 2. select all non zero features
# 3. Update your dataset i.e. X_train,X_test and X_cv so that it contains all rows and only non zero features
# 4. perform hyperparameter tuning and plot either heatmap or 3d plot.
# 5. Fit the best model. Plot ROC AUC curve and confusion matrix similar to model 1.

# %%
def selectKImportance(model, x, k):
    return x[:,model.feature_importances_.argsort()[::-1][:k]]

# %%
dt_tfidf_imp_feature_testModel = DecisionTreeClassifier(class_weight='balanced')
dt_tfidf_imp_feature_testModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
nonzero=0
for i in range (len(dt_tfidf_imp_feature_testModel.feature_importances_)):
    if(dt_tfidf_imp_feature_testModel.feature_importances_[i]>0):
        nonzero=nonzero+1

# %%
nonzero
# Out:
# 1498

# %%
x_train_impfeat_set1=selectKImportance(dt_tfidf_imp_feature_testModel, X_train, nonzero)
x_test_impfeat_set1=selectKImportance(dt_tfidf_imp_feature_testModel, X_test, nonzero)

# %%
x_train_impfeat_set1.shape
# Out:
# (30000, 1498)

# %%
x_test_impfeat_set1.shape
# Out:
# (10000, 1498)

# %%
dt_imp_feat=DecisionTreeClassifier(class_weight='balanced')
parameters={'max_depth':[1, 3, 10, 30], 'min_samples_split':[5, 10, 100, 500]}
clf3=GridSearchCV(dt_imp_feat, parameters, cv=3, scoring='roc_auc', return_train_score=True)

clf3.fit(x_train_impfeat_set1, y_train)
train_auc=clf3.cv_results_['mean_train_score']
train_auc_std=clf3.cv_results_['std_train_score']
cv_auc=clf3.cv_results_['mean_test_score']
cv_auc_std=clf3.cv_results_['std_test_score']
bestMaxdepth_3=clf3.best_params_['max_depth']
bestMINSamplesplit_3=clf3.best_params_['min_samples_split']
bestScore_3=clf3.best_score_
print('~~BEST MAX DEPTH:',bestMaxdepth_3, '~~BEST MIN SAMPLE SPLT:',bestMINSamplesplit_3,
     '~~BEST SCORE:',bestScore_3)
# Out:
# ~~BEST MAX DEPTH: 10 ~~BEST MIN SAMPLE SPLT: 500 ~~BEST SCORE: 0.6370344381348273

# %%
max_scores = pd.DataFrame(clf3.cv_results_).groupby(['param_min_samples_split', 'param_max_depth']).max().unstack(
            )[['mean_test_score', 'mean_train_score']]

fig, ax= plt.subplots(1,2, figsize=(20, 6))

sea.heatmap(max_scores.mean_train_score, annot = True, fmt='.4g', ax=ax[0])
sea.heatmap(max_scores.mean_test_score, annot = True, fmt='.4g', ax=ax[1])

ax[0].set_title('Train')
ax[1].set_title('CV')

plt.show()

# %%
dt_tfidf_testModel=DecisionTreeClassifier(class_weight='balanced', min_samples_split=bestMINSamplesplit_3,
                                          max_depth=bestMaxdepth_3)
dt_tfidf_testModel.fit(x_train_impfeat_set1, y_train)

y_train_pred=dt_tfidf_testModel.predict_proba(x_train_impfeat_set1)[:,1]
predictions_train_set3=dt_tfidf_testModel.predict(x_train_impfeat_set1)

y_test_pred=dt_tfidf_testModel.predict_proba(x_test_impfeat_set1)[:,1]
predictions_test_set3=dt_tfidf_testModel.predict(x_test_impfeat_set1)

train_fpr, train_tpr, tr_thresholds = roc_curve(y_train, y_train_pred)
test_fpr, test_tpr, te_thresholds = roc_curve(y_test, y_test_pred)

ax = plt.subplot()

auc_set3_train=auc(train_fpr, train_tpr)
auc_set3_test=auc(test_fpr, test_tpr)


ax.plot(train_fpr, train_tpr, label="Train AUC ="+str(auc(train_fpr, train_tpr)))
ax.plot(test_fpr, test_tpr, label="Test AUC ="+str(auc(test_fpr, test_tpr)))
plt.legend()
plt.xlabel("False Positive Rate(FPR)")
plt.ylabel("True Positive Rate(TPR)")
plt.title("AUC")
plt.grid(b=True, which='major', color='k', linestyle=':')
ax.set_facecolor("white")
plt.show()

# %%
print('Test confusion matrix')
print(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)))

conf_matr_df_test= pd.DataFrame(confusion_matrix(y_test, predict(y_test_pred, te_thresholds, test_fpr, test_tpr)), 
                                 range(2), range(2))
sns.set(font_scale=1.4)
sns.heatmap(conf_matr_df_test, annot=True,annot_kws={"size": 26}, fmt='g',cmap="YlGnBu")
# Out:
# Test confusion matrix
# the maximum value of tpr*(1-fpr) 0.37165662995334425 for threshold 0.388
# [[ 918  683]
#  [2955 5444]]
# the maximum value of tpr*(1-fpr) 0.37165662995334425 for threshold 0.388
# <AxesSubplot:>

# %%
FP_essay_test_set3=[]
FP_price_test_set3=[]
FP_previous_posted_test_set3=[]

def retrievingfalsepos(part):
    if part=='test':
        FP_test_indexes_set3=[]
        for i in range(len(y_test)):
            if y_test.values[i]==0 and predictions_test_set3[i]==1:
                FP_test_indexes_set3.append(i)
        for i in FP_test_indexes_set3:
            FP_essay_test_set3.append(x_test['essay'].values[i])
            FP_price_test_set3.append(x_test['price'].values[i])
            FP_previous_posted_test_set3.append(x_test['teacher_number_of_previously_posted_projects'].values[i])

# %%
retrievingfalsepos('test')

# %%
def lststr(s):
    str1 =''
    for ele in s:
        str1 += ele
    return str1
    
wordcloud=WordCloud(width=500, height=300, background_color='white', min_font_size=10).generate(lststr(FP_essay_test_set3))

plt.figure(figsize=(8,8), facecolor=None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)

plt.show()

# %%
plt.boxplot(FP_price_test_set3)
plt.title('Box Plot for Price in False Positive')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
 plt.figure(figsize=(10,3))
sns.distplot(FP_previous_posted_test_set3)
plt.title('PDF for Teacher number who previously posted projects in False Positives')
plt.xlabel('Teacher number who previously posted projects')
plt.legend()
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
from prettytable import PrettyTable
x=PrettyTable()

x.field_names= ['Vectorizer', 'Model', 'Hyperparameter', 'AUC']

x.add_row(['TF-IDF', 'SLM', 'split:500 | depth:10', auc_set1_test])
x.add_row(['TF-IDF w2v', 'SLM', 'split:500 | depth:10', auc_set2_test])
x.add_row(['TF-IDF imp feat', 'SLM', 'split:500 | depth:10', auc_set3_test])
print(x)
# Out:
# +-----------------+-------+----------------------+--------------------+
# |    Vectorizer   | Model |    Hyperparameter    |        AUC         |
# +-----------------+-------+----------------------+--------------------+
# |      TF-IDF     |  SLM  | split:500 | depth:10 | 0.6416643842151577 |
# |    TF-IDF w2v   |  SLM  | split:500 | depth:10 | 0.6192915503533591 |
# | TF-IDF imp feat |  SLM  | split:500 | depth:10 | 0.6417815124625571 |
# +-----------------+-------+----------------------+--------------------+
